# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
sim_df = pd.read_csv("sim.csv")

plt.figure(figsize=(10, 8))

ax = sns.heatmap(sim_df.iloc[:100 , :100])
ax.set_xticklabels([])
ax.set_yticklabels([])
plt.show()
